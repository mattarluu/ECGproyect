# %%
import wfdb
import numpy as np
import pandas as pd
import glob
import os
from scipy.signal import resample
import neurokit2 as nk
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Code to load all the signals
basePath="ECG_Database"

## List files and folders insade basePath
patDir = sorted(
    [f.path for f in os.scandir(basePath) if f.is_dir()],
    key=lambda x: int(os.path.basename(x).replace("patient", ""))  # Extraer el número de paciente
)

## Dictionary to store each patient's records
patDict = {}

def generateName(i, extension):
        return f"record{i:03d}{extension}" 

for patient in patDir:
    patID=os.path.basename(patient) # patID = directory name
    archivos = os.listdir(patient)

    # Create 3 lists, one for each file type 
    dat = [f for f in archivos if f.endswith(".dat")]
    hea = [f for f in archivos if f.endswith(".hea")]
    xyz = [f for f in archivos if f.endswith(".xyz")]

    # Rename the files for clarity
    
    import os

    # Agrupar los archivos por nombre base y asignarles un número secuencial
    allFiles = []
    
    # Agrupar los archivos con el mismo nombre base
    for f in dat + hea + xyz: 
        allFiles.append(f)  # Asignar el nuevo nombre

    patDict[patID] = {"files": allFiles}

# %%
for patient, data in patDict.items():
    print(f"Paciente: {patient}")
    
    # Imprimir los archivos del paciente
    if "files" in data:
        print("Archivos:", ", ".join(data["files"]))
    else:
        print("No hay archivos registrados.")
    
    print("-" * 40)
# Out:
# Paciente: patient001
# Archivos: s0010_re.dat, s0016lre.dat, s0014lre.dat, s0016lre.hea, s0014lre.hea, s0010_re.hea, s0016lre.xyz, s0010_re.xyz, s0014lre.xyz
# ----------------------------------------
# Paciente: patient002
# Archivos: s0015lre.dat, s0015lre.hea, s0015lre.xyz
# ----------------------------------------
# Paciente: patient003
# Archivos: s0017lre.dat, s0017lre.hea, s0017lre.xyz
# ----------------------------------------
# Paciente: patient004
# Archivos: s0020are.dat, s0020bre.dat, s0020bre.hea, s0020are.hea, s0020are.xyz, s0020bre.xyz
# ----------------------------------------
# Paciente: patient005
# Archivos: s0021are.dat, s0021bre.dat, s0031lre.dat, s0101lre.dat, s0025lre.dat, s0101lre.hea, s0025lre.hea, s0021are.hea, s0031lre.hea, s0021bre.hea, s0031lre.xyz, s0021bre.xyz, s0021are.xyz, s0025lre.xyz, s0101lre.xyz
# ----------------------------------------
# Paciente: patient006
# Archivos: s0027lre.dat, s0022lre.dat, s0064lre.dat, s0027lre.hea, s0022lre.hea, s0064lre.hea, s0027lre.xyz, s0064lre.xyz, s0022lre.xyz
# ----------------------------------------
# Paciente: patient007
# Archivos: s0038lre.dat, s0026lre.dat, s0078lre.dat, s0029lre.dat, s0078lre.hea, s0038lre.hea, s0026lre.hea, s0029lre.hea, s0026lre.xyz, s0038lre.xyz, s0078lre.xyz, s0029lre.xyz
# ----------------------------------------
# Paciente: patient008
# Archivos: s0028lre.dat, s0068lre.dat, s0037lre.dat, s0037lre.hea, s0068lre.hea, s0028lre.hea, s0068lre.xyz, s0028lre.xyz, s0037lre.xyz
# ----------------------------------------
# Paciente: patient009
# Archivos: s0035_re.dat, s0035_re.hea, s0035_re.xyz
# ----------------------------------------
# Paciente: patient010
# Archivos: s0036lre.dat, s0061lre.dat, s0042lre.dat, s0036lre.hea, s0042lre.hea, s0061lre.hea, s0036lre.xyz, s0042lre.xyz, s0061lre.xyz
# ----------------------------------------
# Paciente: patient011
# Archivos: s0049lre.dat, s0067lre.dat, s0039lre.dat, s0044lre.dat, s0039lre.hea, s0067lre.hea, s0049lre.hea, s0044lre.hea, s0044lre.xyz, s0067lre.xyz, s0039lre.xyz, s0049lre.xyz
# ----------------------------------------
# Paciente: patient012
# Archivos: s0043lre.dat, s0050lre.dat, s0050lre.hea, s0043lre.hea, s0050lre.xyz, s0043lre.xyz
# ----------------------------------------
# Paciente: patient013
# Archivos: s0072lre.dat, s0051lre.dat, s0045lre.dat, s0045lre.hea, s0051lre.hea, s0072lre.hea, s0072lre.xyz, s0045lre.xyz, s0051lre.xyz
# ----------------------------------------
# Paciente: patient014
# Archivos: s0056lre.dat, s0046lre.dat, s0071lre.dat, s0046lre.hea, s0056lre.hea, s0071lre.hea, s0071lre.xyz, s0056lre.xyz, s0046lre.xyz
# ----------------------------------------
# Paciente: patient015
# Archivos: s0057lre.dat, s0152lre.dat, s0047lre.dat, s0152lre.hea, s0047lre.hea, s0057lre.hea, s0047lre.xyz, s0057lre.xyz, s0152lre.xyz
# ----------------------------------------
# Paciente: patient016
# Archivos: s0052lre.dat, s0060lre.dat, s0076lre.dat, s0060lre.hea, s0076lre.hea, s0052lre.hea, s0052lre.xyz, s0060lre.xyz, s0076lre.xyz
# ----------------------------------------
# Paciente: patient017
# Archivos: s0075lre.dat, s0063lre.dat, s0055lre.dat, s0053lre.dat, s0063lre.hea, s0075lre.hea, s0053lre.hea, s0055lre.hea, s0053lre.xyz, s0075lre.xyz, s0055lre.xyz, s0063lre.xyz
# ----------------------------------------
# Paciente: patient018
# Archivos: s0059lre.dat, s0054lre.dat, s0082lre.dat, s0082lre.hea, s0059lre.hea, s0054lre.hea, s0059lre.xyz, s0054lre.xyz, s0082lre.xyz
# ----------------------------------------
# Paciente: patient019
# Archivos: s0077lre.dat, s0070lre.dat, s0058lre.dat, s0070lre.hea, s0058lre.hea, s0077lre.hea, s0077lre.xyz, s0058lre.xyz, s0070lre.xyz
# ----------------------------------------
# Paciente: patient020
# Archivos: s0079lre.dat, s0069lre.dat, s0062lre.dat, s0062lre.hea, s0079lre.hea, s0069lre.hea, s0079lre.xyz, s0069lre.xyz, s0062lre.xyz
# ----------------------------------------
# Paciente: patient021
# Archivos: s0065lre.dat, s0097lre.dat, s0073lre.dat, s0097lre.hea, s0073lre.hea, s0065lre.hea, s0073lre.xyz, s0097lre.xyz, s0065lre.xyz
# ----------------------------------------
# Paciente: patient022
# Archivos: s0074lre.dat, s0149lre.dat, s0066lre.dat, s0149lre.hea, s0074lre.hea, s0066lre.hea, s0149lre.xyz, s0074lre.xyz, s0066lre.xyz
# ----------------------------------------
# Paciente: patient023
# Archivos: s0103lre.dat, s0085lre.dat, s0080lre.dat, s0081lre.dat, s0085lre.hea, s0103lre.hea, s0081lre.hea, s0080lre.hea, s0085lre.xyz, s0103lre.xyz, s0081lre.xyz, s0080lre.xyz
# ----------------------------------------
# Paciente: patient024
# Archivos: s0084lre.dat, s0094lre.dat, s0086lre.dat, s0083lre.dat, s0094lre.hea, s0086lre.hea, s0084lre.hea, s0083lre.hea, s0083lre.xyz, s0086lre.xyz, s0084lre.xyz, s0094lre.xyz
# ----------------------------------------
# Paciente: patient025
# Archivos: s0087lre.dat, s0150lre.dat, s0091lre.dat, s0091lre.hea, s0150lre.hea, s0087lre.hea, s0087lre.xyz, s0091lre.xyz, s0150lre.xyz
# ----------------------------------------
# Paciente: patient026
# Archivos: s0095lre.dat, s0088lre.dat, s0095lre.hea, s0088lre.hea, s0095lre.xyz, s0088lre.xyz
# ----------------------------------------
# Paciente: patient027
# Archivos: s0096lre.dat, s0089lre.dat, s0151lre.dat, s0089lre.hea, s0151lre.hea, s0096lre.hea, s0089lre.xyz, s0096lre.xyz, s0151lre.xyz
# ----------------------------------------
# Paciente: patient028
# Archivos: s0108lre.dat, s0093lre.dat, s0090lre.dat, s0108lre.hea, s0090lre.hea, s0093lre.hea, s0090lre.xyz, s0108lre.xyz, s0093lre.xyz
# ----------------------------------------
# Paciente: patient029
# Archivos: s0098lre.dat, s0092lre.dat, s0122lre.dat, s0098lre.hea, s0092lre.hea, s0122lre.hea, s0092lre.xyz, s0122lre.xyz, s0098lre.xyz
# ----------------------------------------
# Paciente: patient030
# Archivos: s0153lre.dat, s0099lre.dat, s0107lre.dat, s0117lre.dat, s0117lre.hea, s0107lre.hea, s0099lre.hea, s0153lre.hea, s0153lre.xyz, s0107lre.xyz, s0099lre.xyz, s0117lre.xyz
# ----------------------------------------
# Paciente: patient031
# Archivos: s0100lre.dat, s0104lre.dat, s0114lre.dat, s0127lre.dat, s0127lre.hea, s0104lre.hea, s0114lre.hea, s0100lre.hea, s0114lre.xyz, s0127lre.xyz, s0104lre.xyz, s0100lre.xyz
# ----------------------------------------
# Paciente: patient032
# Archivos: s0106lre.dat, s0165lre.dat, s0102lre.dat, s0115lre.dat, s0102lre.hea, s0165lre.hea, s0106lre.hea, s0115lre.hea, s0106lre.xyz, s0115lre.xyz, s0165lre.xyz, s0102lre.xyz
# ----------------------------------------
# Paciente: patient033
# Archivos: s0157lre.dat, s0121lre.dat, s0105lre.dat, s0113lre.dat, s0105lre.hea, s0121lre.hea, s0113lre.hea, s0157lre.hea, s0105lre.xyz, s0121lre.xyz, s0113lre.xyz, s0157lre.xyz
# ----------------------------------------
# Paciente: patient034
# Archivos: s0158lre.dat, s0109lre.dat, s0123lre.dat, s0118lre.dat, s0123lre.hea, s0158lre.hea, s0118lre.hea, s0109lre.hea, s0123lre.xyz, s0118lre.xyz, s0158lre.xyz, s0109lre.xyz
# ----------------------------------------
# Paciente: patient035
# Archivos: s0145lre.dat, s0119lre.dat, s0110lre.dat, s0124lre.dat, s0124lre.hea, s0119lre.hea, s0110lre.hea, s0145lre.hea, s0145lre.xyz, s0119lre.xyz, s0124lre.xyz, s0110lre.xyz
# ----------------------------------------
# Paciente: patient036
# Archivos: s0126lre.dat, s0111lre.dat, s0116lre.dat, s0111lre.hea, s0126lre.hea, s0116lre.hea, s0116lre.xyz, s0111lre.xyz, s0126lre.xyz
# ----------------------------------------
# Paciente: patient037
# Archivos: s0120lre.dat, s0112lre.dat, s0112lre.hea, s0120lre.hea, s0112lre.xyz, s0120lre.xyz
# ----------------------------------------
# Paciente: patient038
# Archivos: s0128lre.dat, s0162lre.dat, s0125lre.dat, s0162lre.hea, s0128lre.hea, s0125lre.hea, s0162lre.xyz, s0125lre.xyz, s0128lre.xyz
# ----------------------------------------
# Paciente: patient039
# Archivos: s0164lre.dat, s0134lre.dat, s0129lre.dat, s0134lre.hea, s0129lre.hea, s0164lre.hea, s0134lre.xyz, s0129lre.xyz, s0164lre.xyz
# ----------------------------------------
# Paciente: patient040
# Archivos: s0130lre.dat, s0219lre.dat, s0133lre.dat, s0131lre.dat, s0131lre.hea, s0130lre.hea, s0133lre.hea, s0219lre.hea, s0130lre.xyz, s0131lre.xyz, s0133lre.xyz, s0219lre.xyz
# ----------------------------------------
# Paciente: patient041
# Archivos: s0132lre.dat, s0138lre.dat, s0136lre.dat, s0276lre.dat, s0132lre.hea, s0138lre.hea, s0276lre.hea, s0136lre.hea, s0276lre.xyz, s0132lre.xyz, s0138lre.xyz, s0136lre.xyz
# ----------------------------------------
# Paciente: patient042
# Archivos: s0140lre.dat, s0347lre.dat, s0135lre.dat, s0137lre.dat, s0135lre.hea, s0140lre.hea, s0347lre.hea, s0137lre.hea, s0140lre.xyz, s0347lre.xyz, s0135lre.xyz, s0137lre.xyz
# ----------------------------------------
# Paciente: patient043
# Archivos: s0278lre.dat, s0141lre.dat, s0144lre.dat, s0144lre.hea, s0141lre.hea, s0278lre.hea, s0141lre.xyz, s0278lre.xyz, s0144lre.xyz
# ----------------------------------------
# Paciente: patient044
# Archivos: s0142lre.dat, s0159lre.dat, s0146lre.dat, s0143lre.dat, s0159lre.hea, s0142lre.hea, s0143lre.hea, s0146lre.hea, s0142lre.xyz, s0146lre.xyz, s0143lre.xyz, s0159lre.xyz
# ----------------------------------------
# Paciente: patient045
# Archivos: s0148lre.dat, s0147lre.dat, s0155lre.dat, s0217lre.dat, s0217lre.hea, s0155lre.hea, s0147lre.hea, s0148lre.hea, s0155lre.xyz, s0217lre.xyz, s0147lre.xyz, s0148lre.xyz
# ----------------------------------------
# Paciente: patient046
# Archivos: s0168lre.dat, s0156lre.dat, s0161lre.dat, s0184lre.dat, s0161lre.hea, s0168lre.hea, s0184lre.hea, s0156lre.hea, s0161lre.xyz, s0184lre.xyz, s0156lre.xyz, s0168lre.xyz
# ----------------------------------------
# Paciente: patient047
# Archivos: s0160lre.dat, s0167lre.dat, s0163lre.dat, s0167lre.hea, s0163lre.hea, s0160lre.hea, s0167lre.xyz, s0160lre.xyz, s0163lre.xyz
# ----------------------------------------
# Paciente: patient048
# Archivos: s0171lre.dat, s0172lre.dat, s0277lre.dat, s0180lre.dat, s0180lre.hea, s0172lre.hea, s0171lre.hea, s0277lre.hea, s0171lre.xyz, s0172lre.xyz, s0180lre.xyz, s0277lre.xyz
# ----------------------------------------
# Paciente: patient049
# Archivos: s0314lre.dat, s0173lre.dat, s0178lre.dat, s0186lre.dat, s0173lre.hea, s0314lre.hea, s0186lre.hea, s0178lre.hea, s0173lre.xyz, s0186lre.xyz, s0178lre.xyz, s0314lre.xyz
# ----------------------------------------
# Paciente: patient050
# Archivos: s0215lre.dat, s0174lre.dat, s0177lre.dat, s0185lre.dat, s0174lre.hea, s0177lre.hea, s0215lre.hea, s0185lre.hea, s0185lre.xyz, s0174lre.xyz, s0215lre.xyz, s0177lre.xyz
# ----------------------------------------
# Paciente: patient051
# Archivos: s0213lre.dat, s0181lre.dat, s0187lre.dat, s0179lre.dat, s0213lre.hea, s0181lre.hea, s0187lre.hea, s0179lre.hea, s0213lre.xyz, s0187lre.xyz, s0181lre.xyz, s0179lre.xyz
# ----------------------------------------
# Paciente: patient052
# Archivos: s0190lre.dat, s0190lre.hea, s0190lre.xyz
# ----------------------------------------
# Paciente: patient053
# Archivos: s0191lre.dat, s0191lre.hea, s0191lre.xyz
# ----------------------------------------
# Paciente: patient054
# Archivos: s0218lre.dat, s0192lre.dat, s0197lre.dat, s0195lre.dat, s0192lre.hea, s0218lre.hea, s0197lre.hea, s0195lre.hea, s0197lre.xyz, s0195lre.xyz, s0192lre.xyz, s0218lre.xyz
# ----------------------------------------
# Paciente: patient055
# Archivos: s0194lre.dat, s0194lre.hea, s0194lre.xyz
# ----------------------------------------
# Paciente: patient056
# Archivos: s0196lre.dat, s0196lre.hea, s0196lre.xyz
# ----------------------------------------
# Paciente: patient057
# Archivos: s0198lre.dat, s0198lre.hea, s0198lre.xyz
# ----------------------------------------
# Paciente: patient058
# Archivos: s0216lre.dat, s0216lre.hea, s0216lre.xyz
# ----------------------------------------
# Paciente: patient059
# Archivos: s0208lre.dat, s0208lre.hea, s0208lre.xyz
# ----------------------------------------
# Paciente: patient060
# Archivos: s0209lre.dat, s0209lre.hea, s0209lre.xyz
# ----------------------------------------
# Paciente: patient061
# Archivos: s0210lre.dat, s0210lre.hea, s0210lre.xyz
# ----------------------------------------
# Paciente: patient062
# Archivos: s0212lre.dat, s0212lre.hea, s0212lre.xyz
# ----------------------------------------
# Paciente: patient063
# Archivos: s0214lre.dat, s0214lre.hea, s0214lre.xyz
# ----------------------------------------
# Paciente: patient064
# Archivos: s0220lre.dat, s0220lre.hea, s0220lre.xyz
# ----------------------------------------
# Paciente: patient065
# Archivos: s0221lre.dat, s0229lre.dat, s0282lre.dat, s0226lre.dat, s0282lre.hea, s0229lre.hea, s0226lre.hea, s0221lre.hea, s0221lre.xyz, s0282lre.xyz, s0226lre.xyz, s0229lre.xyz
# ----------------------------------------
# Paciente: patient066
# Archivos: s0280lre.dat, s0225lre.dat, s0231lre.dat, s0280lre.hea, s0231lre.hea, s0225lre.hea, s0280lre.xyz, s0231lre.xyz, s0225lre.xyz
# ----------------------------------------
# Paciente: patient067
# Archivos: s0230lre.dat, s0283lre.dat, s0227lre.dat, s0283lre.hea, s0230lre.hea, s0227lre.hea, s0283lre.xyz, s0227lre.xyz, s0230lre.xyz
# ----------------------------------------
# Paciente: patient068
# Archivos: s0228lre.dat, s0228lre.hea, s0228lre.xyz
# ----------------------------------------
# Paciente: patient069
# Archivos: s0233lre.dat, s0232lre.dat, s0284lre.dat, s0234lre.dat, s0234lre.hea, s0284lre.hea, s0232lre.hea, s0233lre.hea, s0234lre.xyz, s0233lre.xyz, s0232lre.xyz, s0284lre.xyz
# ----------------------------------------
# Paciente: patient070
# Archivos: s0235lre.dat, s0235lre.hea, s0235lre.xyz
# ----------------------------------------
# Paciente: patient071
# Archivos: s0236lre.dat, s0236lre.hea, s0236lre.xyz
# ----------------------------------------
# Paciente: patient072
# Archivos: s0237lre.dat, s0318lre.dat, s0240lre.dat, s0244lre.dat, s0244lre.hea, s0237lre.hea, s0240lre.hea, s0318lre.hea, s0237lre.xyz, s0244lre.xyz, s0318lre.xyz, s0240lre.xyz
# ----------------------------------------
# Paciente: patient073
# Archivos: s0252lre.dat, s0243lre.dat, s0249lre.dat, s0238lre.dat, s0238lre.hea, s0252lre.hea, s0249lre.hea, s0243lre.hea, s0238lre.xyz, s0243lre.xyz, s0252lre.xyz, s0249lre.xyz
# ----------------------------------------
# Paciente: patient074
# Archivos: s0239lre.dat, s0241lre.dat, s0245lre.dat, s0406lre.dat, s0406lre.hea, s0245lre.hea, s0241lre.hea, s0239lre.hea, s0239lre.xyz, s0245lre.xyz, s0406lre.xyz, s0241lre.xyz
# ----------------------------------------
# Paciente: patient075
# Archivos: s0248lre.dat, s0242lre.dat, s0246lre.dat, s0327lre.dat, s0242lre.hea, s0327lre.hea, s0248lre.hea, s0246lre.hea, s0327lre.xyz, s0246lre.xyz, s0242lre.xyz, s0248lre.xyz
# ----------------------------------------
# Paciente: patient076
# Archivos: s0247lre.dat, s0253lre.dat, s0250lre.dat, s0319lre.dat, s0253lre.hea, s0319lre.hea, s0250lre.hea, s0247lre.hea, s0247lre.xyz, s0319lre.xyz, s0250lre.xyz, s0253lre.xyz
# ----------------------------------------
# Paciente: patient077
# Archivos: s0258lre.dat, s0251lre.dat, s0254lre.dat, s0285lre.dat, s0285lre.hea, s0258lre.hea, s0254lre.hea, s0251lre.hea, s0254lre.xyz, s0258lre.xyz, s0251lre.xyz, s0285lre.xyz
# ----------------------------------------
# Paciente: patient078
# Archivos: s0259lre.dat, s0255lre.dat, s0262lre.dat, s0317lre.dat, s0259lre.hea, s0262lre.hea, s0317lre.hea, s0255lre.hea, s0317lre.xyz, s0255lre.xyz, s0259lre.xyz, s0262lre.xyz
# ----------------------------------------
# Paciente: patient079
# Archivos: s0256lre.dat, s0263lre.dat, s0269lre.dat, s0257lre.dat, s0256lre.hea, s0257lre.hea, s0269lre.hea, s0263lre.hea, s0269lre.xyz, s0256lre.xyz, s0257lre.xyz, s0263lre.xyz
# ----------------------------------------
# Paciente: patient080
# Archivos: s0265lre.dat, s0315lre.dat, s0260lre.dat, s0261lre.dat, s0315lre.hea, s0265lre.hea, s0261lre.hea, s0260lre.hea, s0265lre.xyz, s0261lre.xyz, s0260lre.xyz, s0315lre.xyz
# ----------------------------------------
# Paciente: patient081
# Archivos: s0346lre.dat, s0270lre.dat, s0264lre.dat, s0266lre.dat, s0266lre.hea, s0264lre.hea, s0346lre.hea, s0270lre.hea, s0264lre.xyz, s0346lre.xyz, s0270lre.xyz, s0266lre.xyz
# ----------------------------------------
# Paciente: patient082
# Archivos: s0267lre.dat, s0320lre.dat, s0271lre.dat, s0279lre.dat, s0271lre.hea, s0320lre.hea, s0279lre.hea, s0267lre.hea, s0271lre.xyz, s0320lre.xyz, s0279lre.xyz, s0267lre.xyz
# ----------------------------------------
# Paciente: patient083
# Archivos: s0268lre.dat, s0286lre.dat, s0272lre.dat, s0290lre.dat, s0286lre.hea, s0268lre.hea, s0290lre.hea, s0272lre.hea, s0286lre.xyz, s0272lre.xyz, s0268lre.xyz, s0290lre.xyz
# ----------------------------------------
# Paciente: patient084
# Archivos: s0281lre.dat, s0288lre.dat, s0313lre.dat, s0289lre.dat, s0313lre.hea, s0288lre.hea, s0281lre.hea, s0289lre.hea, s0289lre.xyz, s0288lre.xyz, s0281lre.xyz, s0313lre.xyz
# ----------------------------------------
# Paciente: patient085
# Archivos: s0298lre.dat, s0297lre.dat, s0296lre.dat, s0345lre.dat, s0297lre.hea, s0298lre.hea, s0296lre.hea, s0345lre.hea, s0297lre.xyz, s0298lre.xyz, s0296lre.xyz, s0345lre.xyz
# ----------------------------------------
# Paciente: patient086
# Archivos: s0316lre.dat, s0316lre.hea, s0316lre.xyz
# ----------------------------------------
# Paciente: patient087
# Archivos: s0321lre.dat, s0330lre.dat, s0326lre.dat, s0326lre.hea, s0330lre.hea, s0321lre.hea, s0330lre.xyz, s0321lre.xyz, s0326lre.xyz
# ----------------------------------------
# Paciente: patient088
# Archivos: s0352lre.dat, s0343lre.dat, s0339lre.dat, s0413lre.dat, s0413lre.hea, s0343lre.hea, s0339lre.hea, s0352lre.hea, s0352lre.xyz, s0339lre.xyz, s0413lre.xyz, s0343lre.xyz
# ----------------------------------------
# Paciente: patient089
# Archivos: s0355lre.dat, s0344lre.dat, s0372lre.dat, s0359lre.dat, s0355lre.hea, s0359lre.hea, s0344lre.hea, s0372lre.hea, s0372lre.xyz, s0355lre.xyz, s0344lre.xyz, s0359lre.xyz
# ----------------------------------------
# Paciente: patient090
# Archivos: s0348lre.dat, s0360lre.dat, s0418lre.dat, s0356lre.dat, s0418lre.hea, s0348lre.hea, s0360lre.hea, s0356lre.hea, s0418lre.xyz, s0356lre.xyz, s0348lre.xyz, s0360lre.xyz
# ----------------------------------------
# Paciente: patient091
# Archivos: s0408lre.dat, s0357lre.dat, s0353lre.dat, s0361lre.dat, s0361lre.hea, s0357lre.hea, s0408lre.hea, s0353lre.hea, s0353lre.xyz, s0357lre.xyz, s0408lre.xyz, s0361lre.xyz
# ----------------------------------------
# Paciente: patient092
# Archivos: s0411lre.dat, s0362lre.dat, s0358lre.dat, s0354lre.dat, s0358lre.hea, s0354lre.hea, s0411lre.hea, s0362lre.hea, s0358lre.xyz, s0354lre.xyz, s0362lre.xyz, s0411lre.xyz
# ----------------------------------------
# Paciente: patient093
# Archivos: s0396lre.dat, s0371lre.dat, s0367lre.dat, s0378lre.dat, s0375lre.dat, s0378lre.hea, s0367lre.hea, s0371lre.hea, s0375lre.hea, s0396lre.hea, s0378lre.xyz, s0375lre.xyz, s0371lre.xyz, s0396lre.xyz, s0367lre.xyz
# ----------------------------------------
# Paciente: patient094
# Archivos: s0370lre.dat, s0412lre.dat, s0376lre.dat, s0368lre.dat, s0370lre.hea, s0376lre.hea, s0412lre.hea, s0368lre.hea, s0370lre.xyz, s0412lre.xyz, s0368lre.xyz, s0376lre.xyz
# ----------------------------------------
# Paciente: patient095
# Archivos: s0417lre.dat, s0373lre.dat, s0377lre.dat, s0369lre.dat, s0369lre.hea, s0417lre.hea, s0373lre.hea, s0377lre.hea, s0417lre.xyz, s0373lre.xyz, s0377lre.xyz, s0369lre.xyz
# ----------------------------------------
# Paciente: patient096
# Archivos: s0379lre.dat, s0381lre.dat, s0385lre.dat, s0395lre.dat, s0381lre.hea, s0379lre.hea, s0395lre.hea, s0385lre.hea, s0379lre.xyz, s0381lre.xyz, s0385lre.xyz, s0395lre.xyz
# ----------------------------------------
# Paciente: patient097
# Archivos: s0394lre.dat, s0382lre.dat, s0384lre.dat, s0380lre.dat, s0384lre.hea, s0394lre.hea, s0380lre.hea, s0382lre.hea, s0384lre.xyz, s0394lre.xyz, s0380lre.xyz, s0382lre.xyz
# ----------------------------------------
# Paciente: patient098
# Archivos: s0386lre.dat, s0409lre.dat, s0398lre.dat, s0389lre.dat, s0389lre.hea, s0386lre.hea, s0409lre.hea, s0398lre.hea, s0409lre.xyz, s0398lre.xyz, s0389lre.xyz, s0386lre.xyz
# ----------------------------------------
# Paciente: patient099
# Archivos: s0397lre.dat, s0387lre.dat, s0419lre.dat, s0388lre.dat, s0397lre.hea, s0388lre.hea, s0387lre.hea, s0419lre.hea, s0387lre.xyz, s0419lre.xyz, s0397lre.xyz, s0388lre.xyz
# ----------------------------------------
# Paciente: patient100
# Archivos: s0399lre.dat, s0407lre.dat, s0401lre.dat, s0407lre.hea, s0401lre.hea, s0399lre.hea, s0407lre.xyz, s0401lre.xyz, s0399lre.xyz
# ----------------------------------------
# Paciente: patient101
# Archivos: s0414lre.dat, s0410lre.dat, s0400lre.dat, s0410lre.hea, s0414lre.hea, s0400lre.hea, s0414lre.xyz, s0410lre.xyz, s0400lre.xyz
# ----------------------------------------
# Paciente: patient102
# Archivos: s0416lre.dat, s0416lre.hea, s0416lre.xyz
# ----------------------------------------
# Paciente: patient103
# Archivos: s0332lre.dat, s0332lre.hea, s0332lre.xyz
# ----------------------------------------
# Paciente: patient104
# Archivos: s0306lre.dat, s0306lre.hea, s0306lre.xyz
# ----------------------------------------
# Paciente: patient105
# Archivos: s0303lre.dat, s0303lre.hea, s0303lre.xyz
# ----------------------------------------
# Paciente: patient106
# Archivos: s0030_re.dat, s0030_re.hea, s0030_re.xyz
# ----------------------------------------
# Paciente: patient107
# Archivos: s0199_re.dat, s0199_re.hea, s0199_re.xyz
# ----------------------------------------
# Paciente: patient108
# Archivos: s0013_re.dat, s0013_re.hea, s0013_re.xyz
# ----------------------------------------
# Paciente: patient109
# Archivos: s0349lre.dat, s0349lre.hea, s0349lre.xyz
# ----------------------------------------
# Paciente: patient110
# Archivos: s0003_re.dat, s0003_re.hea, s0003_re.xyz
# ----------------------------------------
# Paciente: patient111
# Archivos: s0203_re.dat, s0203_re.hea, s0203_re.xyz
# ----------------------------------------
# Paciente: patient112
# Archivos: s0169_re.dat, s0169_re.hea, s0169_re.xyz
# ----------------------------------------
# Paciente: patient113
# Archivos: s0018lre.dat, s0018cre.dat, s0018cre.hea, s0018lre.hea, s0018lre.xyz, s0018cre.xyz
# ----------------------------------------
# Paciente: patient114
# Archivos: s0012_re.dat, s0012_re.hea, s0012_re.xyz
# ----------------------------------------
# Paciente: patient115
# Archivos: s0023_re.dat, s0023_re.hea, s0023_re.xyz
# ----------------------------------------
# Paciente: patient116
# Archivos: s0302lre.dat, s0302lre.hea, s0302lre.xyz
# ----------------------------------------
# Paciente: patient117
# Archivos: s0292lre.dat, s0291lre.dat, s0292lre.hea, s0291lre.hea, s0291lre.xyz, s0292lre.xyz
# ----------------------------------------
# Paciente: patient118
# Archivos: s0183_re.dat, s0183_re.hea, s0183_re.xyz
# ----------------------------------------
# Paciente: patient119
# Archivos: s0001_re.dat, s0001_re.hea, s0001_re.xyz
# ----------------------------------------
# Paciente: patient120
# Archivos: s0331lre.dat, s0331lre.hea, s0331lre.xyz
# ----------------------------------------
# Paciente: patient121
# Archivos: s0311lre.dat, s0311lre.hea, s0311lre.xyz
# ----------------------------------------
# Paciente: patient122
# Archivos: s0312lre.dat, s0312lre.hea, s0312lre.xyz
# ----------------------------------------
# Paciente: patient123
# Archivos: s0224_re.dat, s0224_re.hea, s0224_re.xyz
# ----------------------------------------
# Paciente: patient125
# Archivos: s0006_re.dat, s0006_re.hea, s0006_re.xyz
# ----------------------------------------
# Paciente: patient126
# Archivos: s0154_re.dat, s0154_re.hea, s0154_re.xyz
# ----------------------------------------
# Paciente: patient127
# Archivos: s0383lre.dat, s0342lre.dat, s0342lre.hea, s0383lre.hea, s0383lre.xyz, s0342lre.xyz
# ----------------------------------------
# Paciente: patient128
# Archivos: s0182_re.dat, s0182_re.hea, s0182_re.xyz
# ----------------------------------------
# Paciente: patient129
# Archivos: s0189_re.dat, s0189_re.hea, s0189_re.xyz
# ----------------------------------------
# Paciente: patient130
# Archivos: s0166_re.dat, s0166_re.hea, s0166_re.xyz
# ----------------------------------------
# Paciente: patient131
# Archivos: s0273lre.dat, s0273lre.hea, s0273lre.xyz
# ----------------------------------------
# Paciente: patient133
# Archivos: s0393lre.dat, s0393lre.hea, s0393lre.xyz
# ----------------------------------------
# Paciente: patient135
# Archivos: s0334lre.dat, s0334lre.hea, s0334lre.xyz
# ----------------------------------------
# Paciente: patient136
# Archivos: s0205_re.dat, s0205_re.hea, s0205_re.xyz
# ----------------------------------------
# Paciente: patient137
# Archivos: s0392lre.dat, s0392lre.hea, s0392lre.xyz
# ----------------------------------------
# Paciente: patient138
# Archivos: s0005_re.dat, s0005_re.hea, s0005_re.xyz
# ----------------------------------------
# Paciente: patient139
# Archivos: s0223_re.dat, s0223_re.hea, s0223_re.xyz
# ----------------------------------------
# Paciente: patient140
# Archivos: s0019_re.dat, s0019_re.hea, s0019_re.xyz
# ----------------------------------------
# Paciente: patient141
# Archivos: s0307lre.dat, s0307lre.hea, s0307lre.xyz
# ----------------------------------------
# Paciente: patient142
# Archivos: s0351lre.dat, s0351lre.hea, s0351lre.xyz
# ----------------------------------------
# Paciente: patient143
# Archivos: s0333lre.dat, s0333lre.hea, s0333lre.xyz
# ----------------------------------------
# Paciente: patient144
# Archivos: s0341lre.dat, s0341lre.hea, s0341lre.xyz
# ----------------------------------------
# Paciente: patient145
# Archivos: s0201_re.dat, s0201_re.hea, s0201_re.xyz
# ----------------------------------------
# Paciente: patient146
# Archivos: s0007_re.dat, s0007_re.hea, s0007_re.xyz
# ----------------------------------------
# Paciente: patient147
# Archivos: s0211_re.dat, s0211_re.hea, s0211_re.xyz
# ----------------------------------------
# Paciente: patient148
# Archivos: s0335lre.dat, s0335lre.hea, s0335lre.xyz
# ----------------------------------------
# Paciente: patient149
# Archivos: s0202are.dat, s0202bre.dat, s0202are.hea, s0202bre.hea, s0202bre.xyz, s0202are.xyz
# ----------------------------------------
# Paciente: patient150
# Archivos: s0287lre.dat, s0287lre.hea, s0287lre.xyz
# ----------------------------------------
# Paciente: patient151
# Archivos: s0206_re.dat, s0206_re.hea, s0206_re.xyz
# ----------------------------------------
# Paciente: patient152
# Archivos: s0004_re.dat, s0004_re.hea, s0004_re.xyz
# ----------------------------------------
# Paciente: patient153
# Archivos: s0391lre.dat, s0391lre.hea, s0391lre.xyz
# ----------------------------------------
# Paciente: patient154
# Archivos: s0170_re.dat, s0170_re.hea, s0170_re.xyz
# ----------------------------------------
# Paciente: patient155
# Archivos: s0301lre.dat, s0301lre.hea, s0301lre.xyz
# ----------------------------------------
# Paciente: patient156
# Archivos: s0299lre.dat, s0299lre.hea, s0299lre.xyz
# ----------------------------------------
# Paciente: patient157
# Archivos: s0338lre.dat, s0338lre.hea, s0338lre.xyz
# ----------------------------------------
# Paciente: patient158
# Archivos: s0294lre.dat, s0295lre.dat, s0295lre.hea, s0294lre.hea, s0295lre.xyz, s0294lre.xyz
# ----------------------------------------
# Paciente: patient159
# Archivos: s0390lre.dat, s0390lre.hea, s0390lre.xyz
# ----------------------------------------
# Paciente: patient160
# Archivos: s0222_re.dat, s0222_re.hea, s0222_re.xyz
# ----------------------------------------
# Paciente: patient162
# Archivos: s0193_re.dat, s0193_re.hea, s0193_re.xyz
# ----------------------------------------
# Paciente: patient163
# Archivos: s0034_re.dat, s0034_re.hea, s0034_re.xyz
# ----------------------------------------
# Paciente: patient164
# Archivos: s0024are.dat, s0024bre.dat, s0024are.hea, s0024bre.hea, s0024bre.xyz, s0024are.xyz
# ----------------------------------------
# Paciente: patient165
# Archivos: s0322lre.dat, s0323lre.dat, s0323lre.hea, s0322lre.hea, s0322lre.xyz, s0323lre.xyz
# ----------------------------------------
# Paciente: patient166
# Archivos: s0275lre.dat, s0275lre.hea, s0275lre.xyz
# ----------------------------------------
# Paciente: patient167
# Archivos: s0200_re.dat, s0200_re.hea, s0200_re.xyz
# ----------------------------------------
# Paciente: patient168
# Archivos: s0033_re.dat, s0032_re.dat, s0032_re.hea, s0033_re.hea, s0033_re.xyz, s0032_re.xyz
# ----------------------------------------
# Paciente: patient169
# Archivos: s0329lre.dat, s0328lre.dat, s0329lre.hea, s0328lre.hea, s0329lre.xyz, s0328lre.xyz
# ----------------------------------------
# Paciente: patient170
# Archivos: s0274lre.dat, s0274lre.hea, s0274lre.xyz
# ----------------------------------------
# Paciente: patient171
# Archivos: s0364lre.dat, s0364lre.hea, s0364lre.xyz
# ----------------------------------------
# Paciente: patient172
# Archivos: s0304lre.dat, s0304lre.hea, s0304lre.xyz
# ----------------------------------------
# Paciente: patient173
# Archivos: s0305lre.dat, s0305lre.hea, s0305lre.xyz
# ----------------------------------------
# Paciente: patient174
# Archivos: s0325lre.dat, s0324lre.dat, s0300lre.dat, s0325lre.hea, s0324lre.hea, s0300lre.hea, s0324lre.xyz, s0325lre.xyz, s0300lre.xyz
# ----------------------------------------
# Paciente: patient175
# Archivos: s0009_re.dat, s0009_re.hea, s0009_re.xyz
# ----------------------------------------
# Paciente: patient176
# Archivos: s0188_re.dat, s0188_re.hea, s0188_re.xyz
# ----------------------------------------
# Paciente: patient177
# Archivos: s0366lre.dat, s0366lre.hea, s0366lre.xyz
# ----------------------------------------
# Paciente: patient178
# Archivos: s0011_re.dat, s0011_re.hea, s0011_re.xyz
# ----------------------------------------
# Paciente: patient179
# Archivos: s0176_re.dat, s0176_re.hea, s0176_re.xyz
# ----------------------------------------
# Paciente: patient180
# Archivos: s0490_re.dat, s0475_re.dat, s0374lre.dat, s0561_re.dat, s0477_re.dat, s0545_re.dat, s0476_re.dat, s0475_re.hea, s0477_re.hea, s0490_re.hea, s0545_re.hea, s0374lre.hea, s0476_re.hea, s0561_re.hea, s0374lre.xyz, s0475_re.xyz, s0476_re.xyz, s0477_re.xyz, s0490_re.xyz, s0561_re.xyz, s0545_re.xyz
# ----------------------------------------
# Paciente: patient181
# Archivos: s0204bre.dat, s0204are.dat, s0204bre.hea, s0204are.hea, s0204bre.xyz, s0204are.xyz
# ----------------------------------------
# Paciente: patient182
# Archivos: s0308lre.dat, s0308lre.hea, s0308lre.xyz
# ----------------------------------------
# Paciente: patient183
# Archivos: s0175_re.dat, s0175_re.hea, s0175_re.xyz
# ----------------------------------------
# Paciente: patient184
# Archivos: s0363lre.dat, s0363lre.hea, s0363lre.xyz
# ----------------------------------------
# Paciente: patient185
# Archivos: s0336lre.dat, s0336lre.hea, s0336lre.xyz
# ----------------------------------------
# Paciente: patient186
# Archivos: s0293lre.dat, s0293lre.hea, s0293lre.xyz
# ----------------------------------------
# Paciente: patient187
# Archivos: s0207_re.dat, s0207_re.hea, s0207_re.xyz
# ----------------------------------------
# Paciente: patient188
# Archivos: s0365lre.dat, s0365lre.hea, s0365lre.xyz
# ----------------------------------------
# Paciente: patient189
# Archivos: s0309lre.dat, s0309lre.hea, s0309lre.xyz
# ----------------------------------------
# Paciente: patient190
# Archivos: s0040_re.dat, s0041_re.dat, s0040_re.hea, s0041_re.hea, s0041_re.xyz, s0040_re.xyz
# ----------------------------------------
# Paciente: patient191
# Archivos: s0340lre.dat, s0340lre.hea, s0340lre.xyz
# ----------------------------------------
# Paciente: patient192
# Archivos: s0048_re.dat, s0048_re.hea, s0048_re.xyz
# ----------------------------------------
# Paciente: patient193
# Archivos: s0008_re.dat, s0008_re.hea, s0008_re.xyz
# ----------------------------------------
# Paciente: patient194
# Archivos: s0310lre.dat, s0310lre.hea, s0310lre.xyz
# ----------------------------------------
# Paciente: patient195
# Archivos: s0337lre.dat, s0337lre.hea, s0337lre.xyz
# ----------------------------------------
# Paciente: patient196
# Archivos: s0002_re.dat, s0002_re.hea, s0002_re.xyz
# ----------------------------------------
# Paciente: patient197
# Archivos: s0403lre.dat, s0350lre.dat, s0403lre.hea, s0350lre.hea, s0350lre.xyz, s0403lre.xyz
# ----------------------------------------
# Paciente: patient198
# Archivos: s0402lre.dat, s0415lre.dat, s0402lre.hea, s0415lre.hea, s0402lre.xyz, s0415lre.xyz
# ----------------------------------------
# Paciente: patient199
# Archivos: s0404lre.dat, s0404lre.hea, s0404lre.xyz
# ----------------------------------------
# Paciente: patient200
# Archivos: s0405lre.dat, s0405lre.hea, s0405lre.xyz
# ----------------------------------------
# Paciente: patient201
# Archivos: s0423_re.dat, s0420_re.dat, s0423_re.hea, s0420_re.hea, s0420_re.xyz, s0423_re.xyz
# ----------------------------------------
# Paciente: patient202
# Archivos: s0422_re.dat, s0421_re.dat, s0421_re.hea, s0422_re.hea, s0421_re.xyz, s0422_re.xyz
# ----------------------------------------
# Paciente: patient203
# Archivos: s0424_re.dat, s0424_re.hea, s0424_re.xyz
# ----------------------------------------
# Paciente: patient204
# Archivos: s0425_re.dat, s0425_re.hea, s0425_re.xyz
# ----------------------------------------
# Paciente: patient205
# Archivos: s0426_re.dat, s0426_re.hea, s0426_re.xyz
# ----------------------------------------
# Paciente: patient206
# Archivos: s0427_re.dat, s0427_re.hea, s0427_re.xyz
# ----------------------------------------
# Paciente: patient207
# Archivos: s0428_re.dat, s0428_re.hea, s0428_re.xyz
# ----------------------------------------
# Paciente: patient208
# Archivos: s0430_re.dat, s0429_re.dat, s0429_re.hea, s0430_re.hea, s0429_re.xyz, s0430_re.xyz
# ----------------------------------------
# Paciente: patient209
# Archivos: s0431_re.dat, s0431_re.hea, s0431_re.xyz
# ----------------------------------------
# Paciente: patient210
# Archivos: s0432_re.dat, s0432_re.hea, s0432_re.xyz
# ----------------------------------------
# Paciente: patient211
# Archivos: s0433_re.dat, s0433_re.hea, s0433_re.xyz
# ----------------------------------------
# Paciente: patient212
# Archivos: s0434_re.dat, s0434_re.hea, s0434_re.xyz
# ----------------------------------------
# Paciente: patient213
# Archivos: s0435_re.dat, s0435_re.hea, s0435_re.xyz
# ----------------------------------------
# Paciente: patient214
# Archivos: s0436_re.dat, s0436_re.hea, s0436_re.xyz
# ----------------------------------------
# Paciente: patient215
# Archivos: s0437_re.dat, s0437_re.hea, s0437_re.xyz
# ----------------------------------------
# Paciente: patient216
# Archivos: s0438_re.dat, s0438_re.hea, s0438_re.xyz
# ----------------------------------------
# Paciente: patient217
# Archivos: s0439_re.dat, s0439_re.hea, s0439_re.xyz
# ----------------------------------------
# Paciente: patient218
# Archivos: s0440_re.dat, s0440_re.hea, s0440_re.xyz
# ----------------------------------------
# Paciente: patient219
# Archivos: s0441_re.dat, s0441_re.hea, s0441_re.xyz
# ----------------------------------------
# Paciente: patient220
# Archivos: s0442_re.dat, s0442_re.hea, s0442_re.xyz
# ----------------------------------------
# Paciente: patient221
# Archivos: s0443_re.dat, s0443_re.hea, s0443_re.xyz
# ----------------------------------------
# Paciente: patient222
# Archivos: s0444_re.dat, s0444_re.hea, s0444_re.xyz
# ----------------------------------------
# Paciente: patient223
# Archivos: s0446_re.dat, s0445_re.dat, s0446_re.hea, s0445_re.hea, s0446_re.xyz, s0445_re.xyz
# ----------------------------------------
# Paciente: patient224
# Archivos: s0447_re.dat, s0447_re.hea, s0447_re.xyz
# ----------------------------------------
# Paciente: patient225
# Archivos: s0448_re.dat, s0448_re.hea, s0448_re.xyz
# ----------------------------------------
# Paciente: patient226
# Archivos: s0449_re.dat, s0449_re.hea, s0449_re.xyz
# ----------------------------------------
# Paciente: patient227
# Archivos: s0450_re.dat, s0450_re.hea, s0450_re.xyz
# ----------------------------------------
# Paciente: patient228
# Archivos: s0451_re.dat, s0451_re.hea, s0451_re.xyz
# ----------------------------------------
# Paciente: patient229
# Archivos: s0453_re.dat, s0452_re.dat, s0453_re.hea, s0452_re.hea, s0452_re.xyz, s0453_re.xyz
# ----------------------------------------
# Paciente: patient230
# Archivos: s0454_re.dat, s0454_re.hea, s0454_re.xyz
# ----------------------------------------
# Paciente: patient231
# Archivos: s0455_re.dat, s0455_re.hea, s0455_re.xyz
# ----------------------------------------
# Paciente: patient232
# Archivos: s0456_re.dat, s0456_re.hea, s0456_re.xyz
# ----------------------------------------
# Paciente: patient233
# Archivos: s0482_re.dat, s0458_re.dat, s0459_re.dat, s0457_re.dat, s0483_re.dat, s0457_re.hea, s0482_re.hea, s0483_re.hea, s0458_re.hea, s0459_re.hea, s0482_re.xyz, s0457_re.xyz, s0459_re.xyz, s0458_re.xyz, s0483_re.xyz
# ----------------------------------------
# Paciente: patient234
# Archivos: s0460_re.dat, s0460_re.hea, s0460_re.xyz
# ----------------------------------------
# Paciente: patient235
# Archivos: s0461_re.dat, s0461_re.hea, s0461_re.xyz
# ----------------------------------------
# Paciente: patient236
# Archivos: s0462_re.dat, s0463_re.dat, s0464_re.dat, s0464_re.hea, s0463_re.hea, s0462_re.hea, s0463_re.xyz, s0464_re.xyz, s0462_re.xyz
# ----------------------------------------
# Paciente: patient237
# Archivos: s0465_re.dat, s0465_re.hea, s0465_re.xyz
# ----------------------------------------
# Paciente: patient238
# Archivos: s0466_re.dat, s0466_re.hea, s0466_re.xyz
# ----------------------------------------
# Paciente: patient239
# Archivos: s0467_re.dat, s0467_re.hea, s0467_re.xyz
# ----------------------------------------
# Paciente: patient240
# Archivos: s0468_re.dat, s0468_re.hea, s0468_re.xyz
# ----------------------------------------
# Paciente: patient241
# Archivos: s0470_re.dat, s0469_re.dat, s0470_re.hea, s0469_re.hea, s0470_re.xyz, s0469_re.xyz
# ----------------------------------------
# Paciente: patient242
# Archivos: s0471_re.dat, s0471_re.hea, s0471_re.xyz
# ----------------------------------------
# Paciente: patient243
# Archivos: s0472_re.dat, s0472_re.hea, s0472_re.xyz
# ----------------------------------------
# Paciente: patient244
# Archivos: s0473_re.dat, s0473_re.hea, s0473_re.xyz
# ----------------------------------------
# Paciente: patient245
# Archivos: s0474_re.dat, s0480_re.dat, s0474_re.hea, s0480_re.hea, s0474_re.xyz, s0480_re.xyz
# ----------------------------------------
# Paciente: patient246
# Archivos: s0478_re.dat, s0478_re.hea, s0478_re.xyz
# ----------------------------------------
# Paciente: patient247
# Archivos: s0479_re.dat, s0479_re.hea, s0479_re.xyz
# ----------------------------------------
# Paciente: patient248
# Archivos: s0481_re.dat, s0481_re.hea, s0481_re.xyz
# ----------------------------------------
# Paciente: patient249
# Archivos: s0484_re.dat, s0484_re.hea, s0484_re.xyz
# ----------------------------------------
# Paciente: patient250
# Archivos: s0485_re.dat, s0485_re.hea, s0485_re.xyz
# ----------------------------------------
# Paciente: patient251
# Archivos: s0486_re.dat, s0506_re.dat, s0503_re.dat, s0506_re.hea, s0486_re.hea, s0503_re.hea, s0503_re.xyz, s0486_re.xyz, s0506_re.xyz
# ----------------------------------------
# Paciente: patient252
# Archivos: s0487_re.dat, s0487_re.hea, s0487_re.xyz
# ----------------------------------------
# Paciente: patient253
# Archivos: s0488_re.dat, s0488_re.hea, s0488_re.xyz
# ----------------------------------------
# Paciente: patient254
# Archivos: s0489_re.dat, s0489_re.hea, s0489_re.xyz
# ----------------------------------------
# Paciente: patient255
# Archivos: s0491_re.dat, s0491_re.hea, s0491_re.xyz
# ----------------------------------------
# Paciente: patient256
# Archivos: s0492_re.dat, s0492_re.hea, s0492_re.xyz
# ----------------------------------------
# Paciente: patient257
# Archivos: s0493_re.dat, s0493_re.hea, s0493_re.xyz
# ----------------------------------------
# Paciente: patient258
# Archivos: s0494_re.dat, s0494_re.hea, s0494_re.xyz
# ----------------------------------------
# Paciente: patient259
# Archivos: s0495_re.dat, s0495_re.hea, s0495_re.xyz
# ----------------------------------------
# Paciente: patient260
# Archivos: s0496_re.dat, s0496_re.hea, s0496_re.xyz
# ----------------------------------------
# Paciente: patient261
# Archivos: s0497_re.dat, s0497_re.hea, s0497_re.xyz
# ----------------------------------------
# Paciente: patient262
# Archivos: s0498_re.dat, s0498_re.hea, s0498_re.xyz
# ----------------------------------------
# Paciente: patient263
# Archivos: s0499_re.dat, s0499_re.hea, s0499_re.xyz
# ----------------------------------------
# Paciente: patient264
# Archivos: s0500_re.dat, s0500_re.hea, s0500_re.xyz
# ----------------------------------------
# Paciente: patient265
# Archivos: s0501_re.dat, s0501_re.hea, s0501_re.xyz
# ----------------------------------------
# Paciente: patient266
# Archivos: s0502_re.dat, s0502_re.hea, s0502_re.xyz
# ----------------------------------------
# Paciente: patient267
# Archivos: s0504_re.dat, s0504_re.hea, s0504_re.xyz
# ----------------------------------------
# Paciente: patient268
# Archivos: s0505_re.dat, s0505_re.hea, s0505_re.xyz
# ----------------------------------------
# Paciente: patient269
# Archivos: s0508_re.dat, s0508_re.hea, s0508_re.xyz
# ----------------------------------------
# Paciente: patient270
# Archivos: s0507_re.dat, s0507_re.hea, s0507_re.xyz
# ----------------------------------------
# Paciente: patient271
# Archivos: s0509_re.dat, s0509_re.hea, s0509_re.xyz
# ----------------------------------------
# Paciente: patient272
# Archivos: s0510_re.dat, s0510_re.hea, s0510_re.xyz
# ----------------------------------------
# Paciente: patient273
# Archivos: s0511_re.dat, s0511_re.hea, s0511_re.xyz
# ----------------------------------------
# Paciente: patient274
# Archivos: s0512_re.dat, s0512_re.hea, s0512_re.xyz
# ----------------------------------------
# Paciente: patient275
# Archivos: s0513_re.dat, s0513_re.hea, s0513_re.xyz
# ----------------------------------------
# Paciente: patient276
# Archivos: s0526_re.dat, s0526_re.hea, s0526_re.xyz
# ----------------------------------------
# Paciente: patient277
# Archivos: s0527_re.dat, s0527_re.hea, s0527_re.xyz
# ----------------------------------------
# Paciente: patient278
# Archivos: s0529_re.dat, s0530_re.dat, s0528_re.dat, s0530_re.hea, s0529_re.hea, s0528_re.hea, s0530_re.xyz, s0528_re.xyz, s0529_re.xyz
# ----------------------------------------
# Paciente: patient279
# Archivos: s0534_re.dat, s0533_re.dat, s0532_re.dat, s0531_re.dat, s0532_re.hea, s0531_re.hea, s0533_re.hea, s0534_re.hea, s0531_re.xyz, s0532_re.xyz, s0533_re.xyz, s0534_re.xyz
# ----------------------------------------
# Paciente: patient280
# Archivos: s0535_re.dat, s0535_re.hea, s0535_re.xyz
# ----------------------------------------
# Paciente: patient281
# Archivos: s0537_re.dat, s0537_re.hea, s0537_re.xyz
# ----------------------------------------
# Paciente: patient282
# Archivos: s0539_re.dat, s0539_re.hea, s0539_re.xyz
# ----------------------------------------
# Paciente: patient283
# Archivos: s0542_re.dat, s0542_re.hea, s0542_re.xyz
# ----------------------------------------
# Paciente: patient284
# Archivos: s0551_re.dat, s0552_re.dat, s0543_re.dat, s0551_re.hea, s0543_re.hea, s0552_re.hea, s0552_re.xyz, s0543_re.xyz, s0551_re.xyz
# ----------------------------------------
# Paciente: patient285
# Archivos: s0544_re.dat, s0544_re.hea, s0544_re.xyz
# ----------------------------------------
# Paciente: patient286
# Archivos: s0546_re.dat, s0546_re.hea, s0546_re.xyz
# ----------------------------------------
# Paciente: patient287
# Archivos: s0548_re.dat, s0547_re.dat, s0548_re.hea, s0547_re.hea, s0548_re.xyz, s0547_re.xyz
# ----------------------------------------
# Paciente: patient288
# Archivos: s0549_re.dat, s0549_re.hea, s0549_re.xyz
# ----------------------------------------
# Paciente: patient289
# Archivos: s0550_re.dat, s0550_re.hea, s0550_re.xyz
# ----------------------------------------
# Paciente: patient290
# Archivos: s0553_re.dat, s0553_re.hea, s0553_re.xyz
# ----------------------------------------
# Paciente: patient291
# Archivos: s0554_re.dat, s0554_re.hea, s0554_re.xyz
# ----------------------------------------
# Paciente: patient292
# Archivos: s0555_re.dat, s0556_re.dat, s0555_re.hea, s0556_re.hea, s0556_re.xyz, s0555_re.xyz
# ----------------------------------------
# Paciente: patient293
# Archivos: s0558_re.dat, s0557_re.dat, s0558_re.hea, s0557_re.hea, s0557_re.xyz, s0558_re.xyz
# ----------------------------------------
# Paciente: patient294
# Archivos: s0559_re.dat, s0559_re.hea, s0559_re.xyz
# ----------------------------------------

# %%
def get_heart_rate(record):
    
    signal = record.p_signal[:, 0]
    fs = record.fs
    _, rpeaks = nk.ecg_peaks(signal, sampling_rate=fs)
    hr = nk.ecg_rate(rpeaks, sampling_rate=fs)
    return np.mean(hr)

# %%
def get_rr_stdM(record, threshold_factor=0.2):
    signal = record.p_signal[:, 0]  # Usamos la primera derivación
    fs = record.fs
    _, rpeaks = nk.ecg_peaks(signal, sampling_rate=fs)

    # Calcular los intervalos RR (en segundos)
    rr_intervals = np.diff(rpeaks["ECG_R_Peaks"]) / fs
    
    # Calcular la desviación estándar de los intervalos RR
    rr_std = np.std(rr_intervals)
    
    # Calcular la media de los intervalos RR
    rr_mean = np.mean(rr_intervals)
    
    # Determinar si los intervalos RR son irregulares (basado en la desviación estándar)
    is_irregular = rr_std > threshold_factor * rr_mean  # Considera irregular si la desviación estándar es > 20% de la media
    
    return rr_std, is_irregular

# %%
def get_rr_std(record):
    signal = record.p_signal[:, 0]
    fs = record.fs
    _, rpeaks = nk.ecg_peaks(signal, sampling_rate=fs)
    rr_intervals = np.diff(rpeaks["ECG_R_Peaks"]) / fs
    return rr_intervals

# %%
def get_qrs_durationM(record):
    
    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)
    q_peaks = np.array(delineate[1]["ECG_Q_Peaks"])
    s_peaks = np.array(delineate[1]["ECG_S_Peaks"])
    
    durations = (s_peaks - q_peaks) / fs
    durations = durations[~np.isnan(durations)]
    
    return np.mean(durations) if len(durations) > 0 else np.nan

# %%
def get_qrs_features(record, qrs_duration_threshold=120, qrs_amplitude_variation_threshold=0.2):
    """
    Función para extraer las características del complejo QRS, determinar si el QRS es ancho (>120 ms),
    y verificar la alternancia eléctrica (variaciones de amplitud en el QRS).

    Parámetros:
        - file_base: Nombre del archivo base del ECG.
        - qrs_duration_threshold: Umbral de duración del QRS para considerarlo ancho (en ms).
        - qrs_amplitude_variation_threshold: Umbral de variación en la amplitud del QRS para detectar alternancia eléctrica.
        
    Retorna:
        - results: Una lista con las características del complejo QRS, si es ancho, y si hay alternancia eléctrica.
    """

    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)

    results = []
    
    qrs_amplitude_previous = None  # Para comparar la amplitud del QRS en los latidos consecutivos
    alternancia_electrica_detectada = False  # Flag para la alternancia eléctrica

    for i, r_idx in enumerate(rpeaks["ECG_R_Peaks"]):
        try:
            q_idx = delineate[1]["ECG_Q_Peaks"][i]
            s_idx = delineate[1]["ECG_S_Peaks"][i]
            
            # Duración del QRS (en ms)
            qrs_duration = (s_idx - q_idx) * 1000 / fs  # Duración en milisegundos
            
            # Verificar si el QRS es ancho (>120 ms)
            is_qrs_wide = qrs_duration > qrs_duration_threshold

            # Amplitud relativa (como la amplitud del complejo QRS comparada con la onda T)
            q_value = abs(cleaned[q_idx])
            r_value = abs(cleaned[r_idx])
            s_value = abs(cleaned[s_idx])
            qrs_amplitude = q_value + r_value + s_value  # Amplitud total del QRS (suma de los picos Q, R, y S)

            # Verificar si hay alternancia eléctrica (variaciones significativas en la amplitud entre latidos consecutivos)
            if qrs_amplitude_previous is not None:
                amplitude_variation = abs(qrs_amplitude - qrs_amplitude_previous)
                if amplitude_variation > qrs_amplitude_variation_threshold:
                    alternancia_electrica_detectada = True

            # Almacenar la amplitud para el siguiente ciclo
            qrs_amplitude_previous = qrs_amplitude

            results.append({
                "index_QRS": [i + 1, q_idx, r_idx, s_idx],
                "qrs_duration_ms": qrs_duration,
                "qrs_amplitude": qrs_amplitude,
                "is_qrs_wide": is_qrs_wide,
                "electric_alternance": alternancia_electrica_detectada
            })
        except (IndexError, TypeError):
            continue
    
    return results

# %%
def get_qt_intervalM(record):
    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)
    
    q_peaks = np.array(delineate[1]["ECG_Q_Peaks"])
    t_offsets = np.array(delineate[1]["ECG_T_Offsets"])
    
    qt = (t_offsets - q_peaks) / fs
    qt = qt[~np.isnan(qt)]
    
    return np.mean(qt) if len(qt) > 0 else np.nan

# %%
def get_qt_interval(record):
    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)
    
    q_peaks = np.array(delineate[1]["ECG_Q_Peaks"])
    t_offsets = np.array(delineate[1]["ECG_T_Offsets"])
    
    qt = (t_offsets - q_peaks) / fs
    
    
    return qt if len(qt) > 0 else np.nan

# %%
def get_qtc_bazett(record, threshold_ms=500):
    """
    Calcula el QTc (corregido por Bazett) para cada complejo y cuenta los que superan el umbral.
    
    Parámetros:
        - file_base: nombre base del archivo ECG.
        - threshold_ms: umbral en milisegundos para considerar QTc prolongado (por defecto 480 ms).
    
    Retorna:
        - qtc_values: lista de QTc por latido (en ms).
        - count_prolonged: número de QTc > threshold.
    """
    
    signal = record.p_signal[:, 0]
    fs = record.fs

    # QT en segundos por latido
    qt_intervals = get_qt_interval(record)  # debe retornar una lista de QT en segundos
    _, rpeaks = nk.ecg_peaks(signal, sampling_rate=fs)
    
    # RR por latido (mismo largo que QT menos 1)
    r_locs = rpeaks["ECG_R_Peaks"]
    rr_intervals = np.diff(r_locs) / fs  # en segundos
    
    # Asegurar que las longitudes coincidan para el pareo
    min_len = min(len(qt_intervals), len(rr_intervals))
    qt_intervals = qt_intervals[:min_len]
    rr_intervals = rr_intervals[:min_len]
    
    # Calcular QTc latido a latido
    qtc_values = [(qt / np.sqrt(rr)) * 1000 for qt, rr in zip(qt_intervals, rr_intervals)]  # en ms
    count_prolonged = sum(1 for qtc in qtc_values if qtc > threshold_ms)
    
    return {
        "QTc_values_ms": qtc_values,
        "QTc_prolonged_count": count_prolonged
    }

# %%
def get_p_durationM(record):
    
    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)
    
    p_onsets = np.array(delineate[1]["ECG_P_Onsets"])
    p_offsets = np.array(delineate[1]["ECG_P_Offsets"])
    
    durations = (p_offsets - p_onsets) / fs
    durations = durations[~np.isnan(durations)]
    
    return np.mean(durations) if len(durations) > 0 else np.nan

# %%
def get_p_duration(record):
    
    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)
    
    p_onsets = np.array(delineate[1]["ECG_P_Onsets"])
    p_offsets = np.array(delineate[1]["ECG_P_Offsets"])
    
    durations = (p_offsets - p_onsets) / fs
    durations = durations[~np.isnan(durations)]
    
    return durations if len(durations) > 0 else np.nan

# %%
def get_pr_intervalM(record):
    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)
    
    p_onsets = np.array(delineate[1]["ECG_P_Onsets"])
    q_peaks = np.array(delineate[1]["ECG_Q_Peaks"])
    
    pr = (q_peaks - p_onsets) / fs
    pr = pr[~np.isnan(pr)]
    
    return np.mean(pr) if len(pr) > 0 else np.nan

# %%
def get_pr_interval(record):
    signal = record.p_signal[:, 0]  # Usamos todas las derivaciones
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)

    pr_intervals = []
    pr_depression_inferior = False

    p_onsets = delineate[1]["ECG_P_Onsets"]
    q_peaks = delineate[1]["ECG_Q_Peaks"]

    # Identificar índices de derivaciones inferiores
    lead_names = record.sig_name
    inferior_leads = ["II", "III", "aVF"]
    inferior_indices = [i for i, name in enumerate(lead_names) if name in inferior_leads]

    for i in range(min(len(p_onsets), len(q_peaks))):
        try:
            onset = p_onsets[i]
            q_peak = q_peaks[i]

            if onset is None or q_peak is None or q_peak <= onset:
                continue

            # Calcular el intervalo PR (en segundos)
            pr = (q_peak - onset) / fs
            pr_intervals.append(pr)

            # Revisar si hay depresión del PR en derivaciones inferiores
            for idx in inferior_indices:
                pr_segment = cleaned[onset:q_peak, idx]
                baseline = cleaned[onset - 40:onset, idx] if onset >= 40 else cleaned[:onset, idx]
                baseline_mean = np.mean(baseline)
                pr_mean = np.mean(pr_segment)

                if (baseline_mean - pr_mean) > 0.1:  # 0.1 mV de depresión
                    pr_depression_inferior = True
                    break  # Con que ocurra una vez, basta

        except (IndexError, TypeError):
            continue

    return {
        "pr_intervals_s": pr_intervals if len(pr_intervals) > 0 else np.nan,
        "pr_depression_in_inferior_leads": pr_depression_inferior
    }

# %%
def extract_all_features(file_base):
    
    return {
        "heart_rate_mean": get_heart_rate(file_base),
        "rr_std": get_rr_std(file_base),
        "rr_std (mean)": get_rr_stdM(file_base),
        "qrs_duration": get_qrs_duration(file_base),
        "qrs_duration (mean)": get_qrs_durationM(file_base),
        "qt_interval": get_qt_interval(file_base),
        "qt_interval (mean)": get_qt_intervalM(file_base),
        "qtc_bazett": get_qtc_bazett(file_base),
        "p_duration": get_p_duration(file_base),
        "p_duration (mean)": get_p_durationM(file_base),
        "pr_interval": get_pr_interval(file_base),
        "pr_interval (mean)": get_pr_intervalM(file_base)
    }

# %%
def extract_all_featuresM(file_base):
    
    return {
        "heart_rate (mean)": get_heart_rate(file_base),
        "rr_std (mean)": get_rr_stdM(file_base),
        "qrs_duration (mean)": get_qrs_durationM(file_base),
        "qt_interval (mean)": get_qt_intervalM(file_base),
        "qtc_bazett": get_qtc_bazett(file_base),
        "p_duration (mean)": get_p_durationM(file_base),
        "pr_interval (mean)": get_pr_intervalM(file_base)
    }

# %%
def get_q_wave_features(record):

    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)

    results = []
    for i, r_idx in enumerate(rpeaks["ECG_R_Peaks"]):
        try:
            q_idx = delineate[1]["ECG_Q_Peaks"][i]

            q_value = abs(cleaned[q_idx])
            r_value = abs(cleaned[r_idx])

            duration = (r_idx - q_idx) * 1000 / fs  # en milisegundos
            relative_amplitude = q_value / r_value if r_value != 0 else 0

            # Identificación de onda Q patológica:
            q_pathological = False
            # Amplitud Q patológica: > 0.3 mV (300 uV)
            if q_value > 0.3:
                q_pathological = True
            # Duración Q patológica: > 40 ms (0.04 segundos)
            elif duration > 40:
                q_pathological = True

            # Añadir la información de la onda Q patológica a los resultados
            results.append({
                "index_Q": [i + 1, q_idx],
                "duration_Q_ms": duration,
                "Q_amplitude": q_value,
                "relative_amplitude_Q/R": relative_amplitude,
                "Q_pathological": q_pathological
            })
        except (IndexError, TypeError):
            continue

    return results

# %%
def get_p_wave_features(record, p_amplitude_threshold=0.1, p_duration_threshold=150):
    """
    Función para extraer las características de la onda P y determinar si está ausente o alterada.

    Parámetros:
        - file_base: Nombre del archivo base del ECG.
        - p_amplitude_threshold: Umbral de la amplitud de la onda P para considerar que es anómala.
        - p_duration_threshold: Umbral de la duración de la onda P en ms para considerar que es anómala.
        
    Retorna:
        - results: Una lista con las características de las ondas P y si son alteradas o ausentes.
    """
    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)

    results = []
    p_missing = False
    for i in range(len(delineate[1]["ECG_P_Peaks"])):
        try:
            p_idx = delineate[1]["ECG_P_Peaks"][i]
            onset_p = delineate[1]["ECG_P_Onsets"][i]
            offset_p = delineate[1]["ECG_P_Offsets"][i]
            p_value = abs(cleaned[p_idx])

            # Duración de la onda P en ms
            duration_p = (offset_p - onset_p) * 1000 / fs

            # Amplitud relativa (como la amplitud de la onda P comparada con la onda R)
            r_idx = rpeaks["ECG_R_Peaks"][i]
            r_value = abs(cleaned[r_idx]) if cleaned[r_idx] != 0 else 1e-6
            relative_amplitude_p = p_value / r_value

            # Verificar si la onda P es alterada (amplitud o duración fuera de umbrales)
            p_is_altered = (p_value < p_amplitude_threshold) or (duration_p > p_duration_threshold)

            results.append({
                "index_P": [i + 1, delineate[1]["ECG_P_Peaks"][i]],
                "duration_P_ms": duration_p,
                "P_amplitude": p_value,
                "relative_amplitude_P/R": relative_amplitude_p,
                "p_is_altered": p_is_altered
            })
        except (IndexError, TypeError):
            p_missing = True
            continue

    # Si no se encontró ninguna onda P, marcamos como ausente
    if p_missing:
        results.append({"p_missing": True})

    return results

# %%
def get_r_wave_features(record, threshold_r_amplitude=0.5, r_v1_threshold=7):
    """
    Función para extraer las características de la onda R y detectar ondas R altas en las derivaciones precordiales (V1-V6).
    Además, se verifica si la amplitud de R en V1 es mayor a 7 mm.
    
    Parámetros:
        - file_base: Nombre del archivo base del ECG.
        - threshold_r_amplitude: Umbral de amplitud para considerar una onda R como "alta" (en milivoltios).
        - r_v1_threshold: Umbral de amplitud para considerar la onda R en V1 como "alta" (en milímetros).
    
    Retorna:
        - results: Un diccionario con las características de la onda R y la indicación de si hay ondas R altas en las derivaciones precordiales.
    """
    # Cargar los datos del ECG
    
    signal = record.p_signal  # La señal es de varias derivaciones
    fs = record.fs  # Frecuencia de muestreo
    
    # Limpiar la señal
    cleaned = nk.ecg_clean(signal[:, 0], sampling_rate=fs)
    
    # Detectar los picos R
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    
    # Delimitar las derivaciones precordiales (V1 a V6)
    v1_signal = signal[:, 0]  # Derivación V1
    v2_signal = signal[:, 1]  # Derivación V2
    v3_signal = signal[:, 2]  # Derivación V3
    v4_signal = signal[:, 3]  # Derivación V4
    v5_signal = signal[:, 4]  # Derivación V5
    v6_signal = signal[:, 5]  # Derivación V6
    
    # Delimitar las ondas R
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)
    
    results = []
    for i in range(len(delineate[1]["ECG_R_Onsets"])):
        try:
            r_idx = rpeaks["ECG_R_Peaks"][i]
            onset_r = delineate[1]["ECG_R_Onsets"][i]
            offset_r = delineate[1]["ECG_R_Offsets"][i]
            r_value = abs(cleaned[r_idx])

            # Duración de la onda R en milisegundos
            duration_r = (offset_r - onset_r) * 1000 / fs

            # Detectar si la onda R es alta en V1-V6
            r_amplitude_v1 = abs(v1_signal[r_idx])
            r_amplitude_v2 = abs(v2_signal[r_idx])
            r_amplitude_v3 = abs(v3_signal[r_idx])
            r_amplitude_v4 = abs(v4_signal[r_idx])
            r_amplitude_v5 = abs(v5_signal[r_idx])
            r_amplitude_v6 = abs(v6_signal[r_idx])
            
            # Comprobar si alguna onda R es alta (supera el umbral en alguna derivación precordial)
            r_high = any(amplitude > threshold_r_amplitude for amplitude in [r_amplitude_v1, r_amplitude_v2, r_amplitude_v3, r_amplitude_v4, r_amplitude_v5, r_amplitude_v6])
            
            # Verificar si la amplitud de R en V1 es mayor a 7 mm
            r_v1_high = r_amplitude_v1 > r_v1_threshold  # En milímetros, ya que la señal está en milivoltios

            # Añadir los resultados
            results.append({
                "index_R": [i + 1, r_idx],
                "duration_R_ms": duration_r,
                "R_amplitude": r_value,
                "R_high_in_V1_V6": r_high,
                "RV1high": r_v1_high
            })
        except (IndexError, TypeError):
            continue
    return results

# %%
def get_s_wave_features(record):
    signal = record.p_signal[:, 0]
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)

    results = []
    for i, r_idx in enumerate(rpeaks["ECG_R_Peaks"]):
        try:
            s_idx = delineate[1]["ECG_S_Peaks"][i]
            s_value = abs(cleaned[s_idx])
            r_value = abs(cleaned[r_idx])

            # Duración de la onda S en ms
            duration_s = (s_idx - r_idx) * 1000 / fs
            # Amplitud relativa (como la amplitud de la onda S comparada con la onda R)
            relative_amplitude_s = s_value / r_value if r_value != 0 else 0

            results.append({
                "index_S": [i + 1, s_idx],
                "duration_S_ms": duration_s,
                "S_amplitude": s_value,
                "relative_amplitude_S/R": relative_amplitude_s
            })
        except (IndexError, TypeError):
            continue
    return results

# %%
def get_t_wave_features(record):
    
    signal = record.p_signal[:, 0]  # Usamos la primera derivación para simplificar
    fs = record.fs
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)

    results = []

    for i, r_idx in enumerate(delineate[1]["ECG_S_Peaks"]):
        try:
            onset_t = delineate[1]["ECG_T_Onsets"][i]
            offset_t = delineate[1]["ECG_T_Offsets"][i]
            t_idx = delineate[1]["ECG_T_Peaks"][i]
            t_value = abs(cleaned[t_idx])
            r_value = abs(cleaned[r_idx])
            duration_t = (offset_t - onset_t) * 1000 / fs
            relative_amplitude_t = t_value / r_value if r_value != 0 else 0
            t_inverted = cleaned[t_idx] < 0

            # Negatividad en V1 o V2
            t_negative_right_precordial = False
            if record.sig_name[0] in ["V1", "V2"] and cleaned[t_idx] < 0:
                t_negative_right_precordial = True

            # Detección de T bífida: buscar 2 picos dentro del segmento T
            t_segment = cleaned[onset_t:offset_t]
            peaks, _ = find_peaks(t_segment, distance=int(0.05 * fs))  # al menos 50 ms entre picos
            t_bifid = len(peaks) >= 2

            results.append({
                "index_T": [i + 1, t_idx],
                "duration_T_ms": duration_t,
                "T_amplitude": t_value,
                "relative_amplitude_T/R": relative_amplitude_t,
                "T_inverted": t_inverted,
                "T_negative_right_precordial": t_negative_right_precordial,
                "T_bifid": t_bifid
            })
        except (IndexError, TypeError):
            continue

    return results

# %%
def get_st_segment_features(record):
    
    signals = record.p_signal
    fs = record.fs
    leads = record.sig_name

    # Usamos una derivación general para detectar los picos
    signal = signals[:, 0]
    cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)

    results = []

    for i, r_idx in enumerate(rpeaks["ECG_R_Peaks"]):
        try:
            # Estimar inicio del ST (preferimos R_Offset, si no usamos S_Peak)
            st_start = delineate[1]["ECG_R_Offsets"][i]
            if st_start is None:
                st_start = delineate[1]["ECG_S_Peaks"][i]
            st_end = delineate[1]["ECG_T_Onsets"][i]

            if st_start is None or st_end is None or st_end <= st_start:
                continue

            elevated_segment_count = 0
            contiguous_elevated = []
            st_elevated_v1_v3 = False
            brugada_type1 = False

            for ch_idx, lead in enumerate(leads):
                signal = signals[:, ch_idx]

                if st_end >= len(signal):
                    continue

                st_segment = signal[st_start:st_end]
                st_mean = np.mean(st_segment)

                # Contamos cada segmento ST elevado
                if st_mean > 0.1:
                    elevated_segment_count += 1
                    contiguous_elevated.append(lead)

                if lead in ["V1", "V2", "V3"] and st_mean > 0.2:
                    st_elevated_v1_v3 = True

                if lead in ["V1", "V2"]:
                    window = signal[st_start-20:st_end+20]
                    if len(window) > 1 and np.all(np.diff(window) < 0):
                        brugada_type1 = True

            diffuse_st_elevation = elevated_segment_count >= 6

            results.append({
                "index_R": [i + 1, r_idx],
                "ST_elevation_contiguous": len(contiguous_elevated) >= 2,
                "elevated_segment_count": elevated_segment_count,
                "Elevated_V1_V3": st_elevated_v1_v3,
                "Type1": brugada_type1,
                "DiffuseSTElevation": diffuse_st_elevation
            })

        except (IndexError, TypeError, KeyError):
            continue

    return results

# %%
def get_brd_bri_patterns(record, threshold_s_depth=0.2, threshold_r_prime_amplitude=0.1):
    """
    Función para detectar los patrones de RSR' en V1-V2 (bloqueo de rama derecha) y la onda S profunda en I, V5-V6 (bloqueo de rama izquierda).
    
    Parámetros:
        - file_base: Nombre del archivo base del ECG.
        - threshold_s_depth: Umbral para considerar que una onda S es profunda.
        - threshold_r_prime_amplitude: Umbral para detectar una onda R' significativa.
    
    Retorna:
        - results: Un diccionario con los patrones encontrados (RSR' en V1-V2 y onda S profunda en I, V5-V6).
    """
    signal = record.p_signal
    fs = record.fs
    cleaned = nk.ecg_clean(signal[:, 0], sampling_rate=fs)
    
    # Encontrar los picos R para derivaciones
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    
    # Delimitar las derivaciones relevantes por nombre
    v1_signal = signal[:, record.sig_name.index('v1')]  # Usamos el nombre de la derivación 'v1'
    v5_signal = signal[:, record.sig_name.index('v5')]  # Usamos el nombre de la derivación 'v5'
    v6_signal = signal[:, record.sig_name.index('v6')]  # Usamos el nombre de la derivación 'v6'
    
    # Detectar el patrón RSR' en V1 (Bloqueo de Rama Derecha)
    brd_pattern = detect_rsr_pattern(v1_signal, fs, threshold_r_prime_amplitude)
    
    # Detectar la onda S profunda en V5-V6 (Bloqueo de Rama Izquierda)
    bri_pattern = detect_s_wave_depth(v5_signal, v6_signal, fs, threshold_s_depth)
    
    results = {
        "brd_pattern": brd_pattern,
        "bri_pattern": bri_pattern
    }
    
    return results

def detect_rsr_pattern(signal, fs, threshold_r_prime_amplitude):
    """
    Detecta el patrón RSR' en V1-V2, característico de un Bloqueo de Rama Derecha.
    
    Parámetros:
        - signal: La señal ECG en V1 o V2.
        - fs: La frecuencia de muestreo.
        - threshold_r_prime_amplitude: Umbral de amplitud para considerar que una R' es significativa.
    
    Retorna:
        - brd_detected: True si el patrón RSR' se detecta, False de lo contrario.
    """
    
    # Asegurarse de que la señal no esté vacía antes de limpiar
    if signal.size == 0:
        raise ValueError("La señal proporcionada está vacía.")
    
    # Asegurarse de que fs (frecuencia de muestreo) sea un valor válido
    if fs <= 0:
        raise ValueError(f"La frecuencia de muestreo 'fs' no es válida: {fs}")
    
    # Limpiar la señal ECG
    try:
        cleaned = nk.ecg_clean(signal, sampling_rate=fs)
    except Exception as e:
        raise RuntimeError(f"Error al limpiar la señal: {e}")
    
    # Encontrar los picos R
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
    
    # Buscar los picos R, S y R' en la señal de V1
    try:
        delineate = nk.ecg_delineate(signal, sampling_rate=fs, method="dwt", show=False)
    except Exception as e:
        raise RuntimeError(f"Error al delinear la señal ECG: {e}")
    
    r_peaks = rpeaks["ECG_R_Peaks"]  # Esto es un array de índices
    s_peaks = delineate[1]["ECG_S_Peaks"]  # Esto es un array de índices
    
    brd_detected = False
    min_len = min(len(r_peaks) - 1, len(s_peaks))  # -1 para evitar IndexError en r_peaks[i + 1]
    for i in range(1, min_len):  # Verificar en cada complejo
        r_idx = r_peaks[i]
        s_idx = s_peaks[i]
        
        # Detectar una onda R seguida de una onda S y luego una R'
        if r_idx > s_idx and r_idx - s_idx > 30:  # Comprobar que haya suficiente espacio entre R y S
            try:
                r_prime_idx = r_peaks[i + 1]  # Detectar la R' (el siguiente pico R)
                if abs(signal[r_prime_idx]) > threshold_r_prime_amplitude:  # Comprobar que R' sea significativo
                    brd_detected = True
                    break
            except IndexError:
                continue
    
    return brd_detected



def detect_s_wave_depth(v5_signal, v6_signal, fs, threshold_s_depth):
    """
    Detecta una onda S profunda en las derivaciones I, V5, V6, característico de un Bloqueo de Rama Izquierda.
    
    Parámetros:
        - v5_signal: La señal ECG en la derivación V5.
        - v6_signal: La señal ECG en la derivación V6.
        - fs: La frecuencia de muestreo.
        - threshold_s_depth: Umbral para detectar una onda S profunda.
    
    Retorna:
        - bri_detected: True si se detecta una onda S profunda, False de lo contrario.
    """
    # Buscar los picos S en V5 y V6
    delineate_v5 = nk.ecg_delineate(v5_signal, sampling_rate=fs, method="dwt", show=False)
    delineate_v6 = nk.ecg_delineate(v6_signal, sampling_rate=fs, method="dwt", show=False)
    
    s_peaks_v5 = delineate_v5[1]["ECG_S_Peaks"]
    s_peaks_v6 = delineate_v6[1]["ECG_S_Peaks"]
    
    bri_detected = False
    
    # Asegurarse de que los picos S en ambas derivaciones estén alineados
    min_len = min(len(s_peaks_v5), len(s_peaks_v6))
    
    for i in range(min_len):
        s_v5 = s_peaks_v5[i]
        s_v6 = s_peaks_v6[i]
        
        # Asegurarse de que los índices son válidos y dentro del rango
        if s_v5 < len(v5_signal) and s_v6 < len(v6_signal):
            if abs(v5_signal[s_v5]) < -threshold_s_depth and abs(v6_signal[s_v6]) < -threshold_s_depth:
                bri_detected = True
                break
    
    return bri_detected

# %%
def get_sokolow_lyon_index(record, threshold=35):
    """
    Calcula el índice de Sokolow-Lyon: S(V1) + R(V5 o V6).
    Se considera positivo si es mayor al umbral (por defecto 35 mm = 3.5 mV).

    Parámetros:
        - record: Objeto WFDB leído con wfdb.rdrecord(), que contiene el ECG multicanal.
        - threshold: Umbral en mm para considerar el índice positivo (default: 35 mm).

    Retorna:
        - results: Diccionario con amplitudes y si el índice es positivo.
    """
    signal = record.p_signal  # Señales multicanal
    fs = record.fs  # Frecuencia de muestreo

    # Obtener índices de derivaciones V1, V5 y V6
    try:
        idx_v1 = record.sig_name.index('v1')
        idx_v5 = record.sig_name.index('v5')
        idx_v6 = record.sig_name.index('v6')
    except ValueError as e:
        raise ValueError(f"No se encontraron derivaciones necesarias en el registro: {e}")

    # Extraer señales individuales
    v1_signal = signal[:, idx_v1]
    v5_signal = signal[:, idx_v5]
    v6_signal = signal[:, idx_v6]

    # Limpiar una señal para detección de R peaks (puede ser V5 o cualquier canal estable)
    cleaned = nk.ecg_clean(v5_signal, sampling_rate=fs)
    _, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)

    # Delineado en V1 para obtener picos S
    try:
        delineate_v1 = nk.ecg_delineate(v1_signal, rpeaks["ECG_R_Peaks"], sampling_rate=fs, method="dwt", show=False)
    except IndexError:
        delineate_v1 = nk.ecg_delineate(v1_signal, rpeaks["ECG_R_Peaks"], sampling_rate=fs, method="peak", show=False)

    # Extraer picos
    s_peaks_v1 = delineate_v1[1].get("ECG_S_Peaks", [])
    r_peaks = rpeaks["ECG_R_Peaks"]

    # Asegurar que los índices estén dentro del tamaño de cada señal
    s_amplitudes_v1 = [abs(v1_signal[i]) for i in s_peaks_v1 if i < len(v1_signal)]
    r_amplitudes_v5 = [abs(v5_signal[i]) for i in r_peaks if i < len(v5_signal)]
    r_amplitudes_v6 = [abs(v6_signal[i]) for i in r_peaks if i < len(v6_signal)]

    # Calcular máximas amplitudes
    s_amplitude_v1 = max(s_amplitudes_v1) if s_amplitudes_v1 else 0
    r_amplitude_v5 = max(r_amplitudes_v5) if r_amplitudes_v5 else 0
    r_amplitude_v6 = max(r_amplitudes_v6) if r_amplitudes_v6 else 0

    # Índice de Sokolow-Lyon = S en V1 + mayor R en V5/V6
    r_amplitude_max = max(r_amplitude_v5, r_amplitude_v6)
    sokolow_lyon_index = s_amplitude_v1 + r_amplitude_max

    # Evaluar si es positivo según el umbral
    is_positive = sokolow_lyon_index > threshold

    results = {
        "S_in_V1_amplitude_mm": s_amplitude_v1,
        "R_in_V5_amplitude_mm": r_amplitude_v5,
        "R_in_V6_amplitude_mm": r_amplitude_v6,
        "Sokolow_Lyon_index_mm": sokolow_lyon_index,
        "Index_positive": is_positive
    }

    return results

# %%
def extraer_caracteristicas(patient_id, archivo):
    features={}
    basePath = "ECG_Database"
    file_path = os.path.join(basePath, patient_id, archivo)
    file_base = os.path.splitext(file_path)[0]
    record = wfdb.rdrecord(file_base)
    
    heart_rate=get_heart_rate(record)
    rrM=get_rr_stdM(record)
    rr=get_rr_std(record)
    qrsM=get_qrs_durationM(record) 
    qrs=get_qrs_features(record)   
    qtM=get_qt_intervalM(record)
    qt=get_qt_interval(record)
    qtc=get_qtc_bazett(record)
    prM=get_pr_intervalM(record)
    pr=get_pr_interval(record)
    q=get_q_wave_features(record)
    p=get_p_wave_features(record)
    r=get_r_wave_features(record)
    s=get_s_wave_features(record)
    t=get_t_wave_features(record)
    st=get_st_segment_features(record)
    br=get_brd_bri_patterns(record)
    sokolow=get_sokolow_lyon_index(record)
    

    
    record_features={"heart_rate":heart_rate, "rrM":rrM, "rr":rr, "qrsM":qrsM, "qrs":qrs, "qtM":qtM, "qt":qt, "qtc":qtc, "prM":prM, "pr":pr, "q_wave":q, "p_wave":p, "r_wave":r, "s_wave":s, "t_wave":t, "st_segment":st, "br": br, "sokolow":sokolow} 
# Almacenar las características
    features[patient_id]={archivo:record_features}

    return features

# %%
def possible_infarct(patient_id, archivo, caracteristicas):
    patient_features = caracteristicas[patient_id]

# Acceder a las características específicas del archivo
    archivo_features = patient_features[archivo]

# Acceder a la lista de resultados de ST (que contiene diccionarios con las características ST)
    st_results = archivo_features["st_segment"]

# Ahora, 'st_results' es una lista de diccionarios con los resultados de ST, por lo que puedes acceder a la característica 'ST_elevation_contiguous' así:
    st_elevated_contiguous=False
    for result in st_results:
        st_elevation = result["ST_elevation_contiguous"]
        if st_elevation==True:
            st_elevated_contiguous=True
            break
    # Acceder a la lista de resultados de ST (que contiene diccionarios con las características ST)
    t_wave = archivo_features["t_wave"]

    # Ahora, 'st_results' es una lista de diccionarios con los resultados de ST, por lo que puedes acceder a la característica 'ST_elevation_contiguous' así:
    t_inverted=False
    for result in t_wave:
        t = result["T_inverted"]
        if t==True:
            t_inverted=True
            break
    
    q_wave =  archivo_features["q_wave"]
    q_pathological=False
    for result in q_wave:
        q = result["Q_pathological"]
        if q==True:
            q_pathological=True
            break
    
    qrs =  archivo_features["qrs"]
    qrs_wide=False
    for result in qrs:
        qrs_= result["is_qrs_wide"]
        if qrs_==True:
            qrs_wide=True
            break
    

    possible=0
    if(st_elevated_contiguous):
        possible=possible+50
    if(t_inverted):
        possible=possible+18
    if(q_pathological):
        possible=possible+22
    if(qrs_wide):
        possible=possible+10
    
    return possible

# %%
def possible_arrhythmia(patient_id, archivo, caracteristicas):
    
    rr_irregular = caracteristicas[patient_id][archivo]["rrM"][1]
    patient_features = caracteristicas[patient_id]

    # Acceder a las características específicas del archivo
    archivo_features = patient_features[archivo]

    # Acceder a la lista de resultados de ST (que contiene diccionarios con las características ST)
    p_results = archivo_features["p_wave"]

    # Ahora, 'st_results' es una lista de diccionarios con los resultados de ST, por lo que puedes acceder a la característica 'ST_elevation_contiguous' así:
    p_altered=False
    for result in p_results:
        p = result["p_is_altered"]
        if p==True:
            p_altered=True
            break
    
    bad_HR = caracteristicas[patient_id][archivo]["heart_rate"]>150
    pr_prolonged=caracteristicas[patient_id][archivo]["prM"]>200

    possible=0
    if(rr_irregular):
        possible=possible+40
    if(p_altered):
        possible=possible+25
    if(bad_HR):
        possible=possible+20
    if(pr_prolonged):
        possible=possible+15
    
    return possible

# %%
def possible_branch_block(patient_id, archivo, caracteristicas):
    
    patient_features = caracteristicas[patient_id]

    # Acceder a las características específicas del archivo
    archivo_features = patient_features[archivo]

    # Acceder a la lista de resultados de ST (que contiene diccionarios con las características ST)
    qrs_results = archivo_features["qrs"]

    # Ahora, 'st_results' es una lista de diccionarios con los resultados de ST, por lo que puedes acceder a la característica 'ST_elevation_contiguous' así:
    qrs_wide=False
    for result in qrs_results:
        qrs = result["is_qrs_wide"]
        if qrs==True:
            qrs_wide=True
            break

    if (caracteristicas[patient_id][archivo]["br"]['brd_pattern']):
        bb_pattern=True
    else:
        bb_pattern=caracteristicas[patient_id][archivo]["br"]['bri_pattern']

    possible=0
    if(qrs_wide):
        possible=possible+100
    if(bb_pattern):
        possible=possible+80
    
    possible=min(possible, 100)
    
    return possible

# %%
def possible_ventricular_hypertrophy(patient_id, archivo, caracteristicas):
    
    patient_features = caracteristicas[patient_id]

    # Acceder a las características específicas del archivo
    archivo_features = patient_features[archivo]

    # Acceder a la lista de resultados de ST (que contiene diccionarios con las características ST)
    r_results = archivo_features["r_wave"]

    # Ahora, 'st_results' es una lista de diccionarios con los resultados de ST, por lo que puedes acceder a la característica 'ST_elevation_contiguous' así:
    r_high=False
    for result in r_results:
        r = result["R_high_in_V1_V6"]
        if r==True:
            r_high=True
            break
    rV1_high=False
    for result in r_results:
        r = result["RV1high"]
        if r==True:
            rV1_high=True
            break
    
    sokolow_positive =   caracteristicas[patient_id][archivo]["sokolow"]["Index_positive"]
    
    

    possible=0
    if(r_high):
        possible=possible=40

    if(rV1_high):
        possible=possible+40
    
    if(sokolow_positive): 
        possible=possible+20
    
    
    return possible

# %%
def possible_long_QT_syndrome(patient_id, archivo, caracteristicas):

    qt = caracteristicas[patient_id][archivo]["qtc"]["QTc_prolonged_count"]
    qt_prolonged=False
    if(qt>0):
        qt_prolonged=True
    
    patient_features = caracteristicas[patient_id]

    # Acceder a las características específicas del archivo
    archivo_features = patient_features[archivo]

    # Acceder a la lista de resultados de ST (que contiene diccionarios con las características ST)
    t_results = archivo_features["t_wave"]
    
    t_bifid=False
    
    for result in t_results:
        r = result["T_bifid"]
        if r==True:
            t_bifid=True
            break
    possible=0
    if(qt_prolonged):
        possible=possible+60

    if(t_bifid):
        possible=possible+40
   
    
    return possible

# %%
def possible_brugada_syndrome(patient_id, archivo, caracteristicas):
    patient_features = caracteristicas[patient_id]

    # Acceder a las características específicas del archivo
    archivo_features = patient_features[archivo]

    # Acceder a la lista de resultados de ST (que contiene diccionarios con las características ST)
    st_results = archivo_features["st_segment"]

    st_elevated=False
    
    for result in st_results:
        r = result["Elevated_V1_V3"]
        if r==True:
            st_elevated=True
            break
    
    pr=caracteristicas[patient_id][archivo]["pr"]["pr_depression_in_inferior_leads"]

    qrs_results = archivo_features["qrs"]

    electric=False
    
    for result in qrs_results:
        r = result["electric_alternance"]
        if r==True:
            electric=True
            break

    possible=0
    if(st_elevated):
        possible=possible+70

    if(pr):
        possible=possible+40
    
    if(electric):
        possible=possible+10
    possible=min(possible, 100)
   
    
    return possible

# %%
def possible_pericarditis(patient_id, archivo, caracteristicas):

    patient_features = caracteristicas[patient_id]

    # Acceder a las características específicas del archivo
    archivo_features = patient_features[archivo]

    # Acceder a la lista de resultados de ST (que contiene diccionarios con las características ST)
    st_results = archivo_features["st_segment"]

    st_elevated=False
    
    for result in st_results:
        r = result["DiffuseSTElevation"]
        if r==True:
            st_elevated=True
            break

    t_results = archivo_features["t_wave"]

    t_negative=False
    
    for result in t_results:
        r = result["T_negative_right_precordial"]
        if r==True:
            t_negative=True
            break

    type1=False
    
    for result in st_results:
        r = result["Type1"]
        if r==True:
            type1=True
            break

    
    
    

    possible=0
    if(st_elevated):
        possible=possible+50

    if(t_negative):
        possible=possible+30
    
    if(type1):
        possible=possible+20
    possible=min(possible, 100)
   
    
    return possible

# %%
patient_features = allFeatures["patient001"]

# Acceder a las características específicas del archivo
archivo_features = patient_features["s0010_re.dat"]

# Acceder a la lista de resultados de ST (que contiene diccionarios con las características ST)
st_results = archivo_features["st_segment"]

st_elevated=False

for result in st_results:
    r = result["DiffuseSTElevation"]
    if r==True:
        st_elevated=True
        break

t_results = archivo_features["t_wave"]

t_negative=False

for result in t_results:
    r = result["T_negative_right_precordial"]
    if r==True:
        t_negative=True
        break

type1=False

for result in st_results:
    r = result["Type1"]
    if r==True:
        type1=True
        break


sokolow_positive =   allFeatures["patient001"]["s0010_re.dat"]["sokolow"]["Index_positive"]
print(st_elevated, t_negative, type1)
# Out:
# True False False

# %%
caracteristicas=extraer_caracteristicas("patient001", "s0010_re.dat")
print(caracteristicas)

# %%
allFeatures = {}

for patient_id, data in patDict.items():
    archivos = data["files"]
    dat_files = [f for f in archivos if f.endswith(".dat")]
    
    patient_features = {}  # Dict para todos los archivos de este paciente
    
    for archivo in dat_files:
        features = extraer_caracteristicas(patient_id, archivo)
        patient_features.update(features[patient_id])  # Extraemos solo el contenido interno
    
    allFeatures[patient_id] = patient_features

# %%
infarct=possible_infarct("patient001", "s0010_re.dat", allFeatures)
arrhythmia=possible_arrhythmia("patient001", "s0010_re.dat", allFeatures)
branch_block=possible_branch_block("patient001", "s0010_re.dat", allFeatures)
ventricular_hypertrophy=possible_ventricular_hypertrophy("patient001", "s0010_re.dat", allFeatures)
long_QT_syndrome=possible_long_QT_syndrome("patient001", "s0010_re.dat", allFeatures)
brugada_syndrome=possible_brugada_syndrome("patient001", "s0010_re.dat", allFeatures)
pericarditis=possible_pericarditis("patient001", "s0010_re.dat", allFeatures)

print(f"possible_infarct:{infarct}, possible_arrhythmia:{arrhythmia}, possible_branch_block:{branch_block}, possible_ventricular_hypertrophy:{ventricular_hypertrophy}, possible_long_QT_syndrome:{long_QT_syndrome}, possible_brugada_syndrome:{brugada_syndrome}, possible_pericarditis:{pericarditis}")
# Out:
# possible_infarct:40, possible_arrhythmia:25, possible_branch_block:0, possible_ventricular_hypertrophy:40, possible_long_QT_syndrome:60, possible_brugada_syndrome:0, possible_pericarditis:70

# %%
print(allFeatures)

# %%
basePath = "patient001"
file_path = os.path.join(basePath, "s0010_re.dat")
file_base = os.path.splitext(file_path)[0]
record = wfdb.rdrecord(file_base)
signal = record.p_signal[:, 0]  # Todas las derivaciones
fs = record.fs
cleaned = nk.ecg_clean(signal, sampling_rate=fs)
_, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)

# %%
def aplicar_kmeans(features, num_clusters=7):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    clusters = kmeans.fit_predict(features)
    return clusters, kmeans

# %%
caracteristicas=extraer_caracteristicas()
print(caracteristicas)

# %%
basePath = "patient001"
file_path = os.path.join(basePath, "s0010_re.dat")
file_base = os.path.splitext(file_path)[0]
record = wfdb.rdrecord(file_base)
signal = record.p_signal[:, 0]
fs = record.fs
cleaned = nk.ecg_clean(signal, sampling_rate=fs)
_, rpeaks = nk.ecg_peaks(cleaned, sampling_rate=fs)
delineate = nk.ecg_delineate(cleaned, rpeaks, sampling_rate=fs, method="dwt", show=False)

for i,r_idx in enumerate(rpeaks["ECG_R_Peaks"]):
    q_idx=delineate[1]["ECG_Q_Peaks"][i]
    q_value = abs(cleaned[q_idx])
    r_value = abs(cleaned[r_idx])

    duration = (r_idx - q_idx) * 1000 / fs  # en milisegundos
    relative_amplitude = q_value / r_value if r_value != 0 else 0
    print(q_value)

# %%
#get_q_wave
for patient_id, data in patDict.items():
    archivos = data["files"]
    dat_files = [f for f in archivos if f.endswith(".dat")]
    hea_files = [f for f in archivos if f.endswith(".hea")]
    i=0
    print(f"Files of: {patient_id}")
    for archivo in dat_files:
        basePath = "ECG_Database"
        file_path = os.path.join(basePath, patient_id, archivo)
        file_base = os.path.splitext(file_path)[0]
        qwaves=get_r_wave_features(file_base)
        print(f"Record ({archivo}):", qwaves)

# %%
#extract_all_features
for patient_id, data in patDict.items():
    archivos = data["files"]
    dat_files = [f for f in archivos if f.endswith(".dat")]
    hea_files = [f for f in archivos if f.endswith(".hea")]
    i=0
    print(f"Files of: {patient_id}")
    for archivo in dat_files:
        basePath = "ECG_Database"
        file_path = os.path.join(basePath, patient_id, archivo)
        file_base = os.path.splitext(file_path)[0]
        features = extract_all_featuresM(file_base)
        print(f"Record ({archivo}):", features)
